# %% [markdown]
# ## Requirements
# * [Chrome Driver](https://chromedriver.chromium.org/downloads)
# * Selenium
#
# ### Thought Works
# * Consider using webdriver-manager to streamline installation of chrome driver
#
# ### Proved our Proof of Concept
# Now that we are able to successfully scrape information from the website, we want to speed up our implementation. At the moment, a few bottlenecks are:
# * We have to wait until the webdriver is fully initialized before we start making request to our page, slowing down our implementation due to the sleep timer I've added. I believe that once the webdriver is initialized, we only have to wait for the webpage to load once for each company. Since there are 531 companies and each company webpage could potentially take 3 seconds to load (based on our current network connection) we'd be waiting a minimum of 27 minutes to acquire our information. This implementation is not robust because we assume a stable network connection. A more robust implementation would wait until the page has fully loaded. This should be implemented in a future iteration.

# %%
import bs4
import math
import multiprocessing as mp
import pandas as pd
import requests
import selenium
import time

from bs4 import BeautifulSoup
from collections import namedtuple
from pyvirtualdisplay import Display
from selenium import webdriver
from selenium.webdriver import DesiredCapabilities
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

# %% [markdown]
# ### Configuration
# The cell below contains useful information that is used throughout our web scraping algorithm.

# %%
BASE_COMPANY_URL = "https://sloanreview.mit.edu/culture500/company/c"
COMPANY_VALUES = {
    "Agility": "agility",
    "Collaboration": "collaboration",
    "Customer": "customer",
    "Diversity": "inclusivity",
    "Execution": "execution",
    "Innovation": "innovation",
    "Integrity": "integrity",
    "Performance": "performance",
    "Respect": "respect",
}
HEADERS = [
    "frequency_score",
    "sentiment_score",
    "value",
    "company"
]
PATH_TO_CHROME_DRIVER = "/Users/jamosa/bin/chromedriver"
CHROME_OPTIONS = Options()
CHROME_OPTIONS.headless = True
CHROME_OPTIONS.add_argument("--window-size=1920x1080")
COMPANY_START = 101
COMPANY_END = 631
CAPABILITIES = DesiredCapabilities.CHROME.copy()
CAPABILITIES['acceptSslCerts'] = True 
CAPABILITIES['acceptInsecureCerts'] = True

# %% [markdown]
# ### Fsvc
# Fsvc is a named tuple that makes dealing with the information we've scraped and store easier. It'll allow me to access information using highly descriptive names instead of seemingly arbitrary numerical indices.

# %%
# Named tuple for hold frequency score, sentiment score, company value, and company name
Fsvc = namedtuple("Fsvc", " ".join(HEADERS))

# %% [markdown]
# ### partition
# Partition quite literally mimicks a mathematical partition. Given some number, a desired number of subsets, and an optional offset, we generate a list of evenly separted values.

# %%
def partition(value, num_slices, offset=0):
    """Creates an approximately even partition of some whole number."""
    hop = value // num_slices
    indices = [math.floor(ndx * hop) + offset for ndx in range(num_slices)]
    indices.append(value + offset)
    
    return indices

partition(531, 2, 101)
# Out:
# [101, 366, 632]

# %% [markdown]
# ### parse_page_by_tag_and_classes
# This function is very unique in the sense that it might not be very intuitive, but it serves a purpose that allows me to reduce the amount of code I write. I found myself typing in the following logic multiple times, so to reduce the multiplicity of doing so, also know as being DRY (Don't Repeat Yourself), I extracted the core logic of retrieving text from some tag with specific classes into a function.

# %%
def parse_page_by_tag_and_classes(
    scraper : bs4.BeautifulSoup,
    tag : str,
    classes : str
    ) -> str:
    """Returns the text associated with the first instance of `tag` with classes `classes`
    
    :param scraper: an instance of bs4 web scraper already loaded with the document's html
    :param tag: the tage element to search for without the brackets
    :param classes: the classes of interest associated with the tag separated by spaces
    :return: a string of text
    """
    tag_elem = scraper.find(tag, {"class": classes})
    return tag_elem.get_text()

# %% [markdown]
# ## Company URL
# The URL associated with each company is relatively the same. The offset for a companies index is 100, so the first company's information can be found at `https://sloanreview.mit.edu/culture500/company/c101` which is the company `3M`. Therefore, information associated with all companies listed on the Culture 500 page can be found by modifying the last 3 characters of the URL with values in the range of 101 and 631, inclusive.
#
# ## Singleton Inspection
# So, questions! Now we need to examine a single instance and see if we can successfully scrape information form the site.
# * Can we successfully scrape information about a single instance?
#     * Yes
# * Do all instances follow the same structure?
#     * Yes

# %% [markdown]
# ### retrieve_company_values
# This function, given the company's index and a web driver object, get's all of the information from the current company's culture500 page and saves such information to a list of tuples. The information is then returned to the user. This function contains the majority of our logic and required countless experimenting in order to determine the underlying structure of the page.

# %%
def retrieve_company_values(
    company_ndx : int,
    browser : selenium.webdriver.chrome.webdriver.WebDriver
    ) -> None:
    """Retrieve information about a company's values.
    
    There are 531 companies listed at `https://sloanreview.mit.edu/culture500/research/#company-list`
    and each company has a numerical value associated with where it is located on their servers. The
    starting index is 101 and subsequent companies, in alphabetical order, follow by simply adding 1
    to the previous index until 632 is reached.
    
    Example company url: `https://sloanreview.mit.edu/culture500/company/c101` --> 3M 
    
    :param company_ndx: the company's numerical value as listed on the site
    """
    # Request web page
    company_info = []
    cur_value = ""
    company_url = f"https://sloanreview.mit.edu/culture500/company/c{company_ndx}"
    browser.get(company_url)
    
    # Needs to wait until graph is loaded - classes associated with graph ==> .sc-bdVaJa .sc-bwzfXH .pjOvZ
    delay = 3
    graph_elem = (
        WebDriverWait(browser, delay)
        .until(EC.visibility_of_element_located(
            (By.CSS_SELECTOR, ".sc-bdVaJa.sc-bwzfXH.pjOvZ")
        ))
    )
    
    # All buttons associated with company values have the same class name
    cv_buttons = browser.find_elements_by_class_name("sc-bdVaJa.sc-EHOje.bubble-sidebar-button.sc-gqjmRU.eiaGtK")
    time.sleep(2)
    for button in cv_buttons:
        # Get current value
        cur_value = button.text
        # Grab all links and simulate a click action
        button.click()
#         time.sleep(.3)
        # Grab the updated pages content
        updated_page_html = browser.page_source
        # Initialize web scraper with current companies html page
        scraper = BeautifulSoup(updated_page_html, "html.parser")
        # Get frequency score and sentiment score
        text = parse_page_by_tag_and_classes(scraper, "div", "sc-bdVaJa sc-htpNat hALkol")
        text = text.replace("Sentiment Score: ", " ").replace("Frequency Score: ", "")
        freq_score, sent_score = text.split(" ")
        # Get company name
        company_name = parse_page_by_tag_and_classes(scraper, "div", "sc-bdVaJa sc-bwzfXH jruoDg")
        # Add information to container
        fsvc = Fsvc(freq_score, sent_score, cur_value, company_name)
        company_info.append(fsvc)
    
    return company_info

# %% [markdown]
# ## Next Steps - Gotta Catch 'Em All
# Now that we are able to successfully scrape information about any one company, we introduce a loop into our program to get information about all companies. This part also took some thinking outside of the box. We are able to seamlessly scrape information from culture500, but the window popping up became rather bothersome and quite unneccessary. So, insteading of having our browser (Chrome, in this case) pop up for each company, we modified our configuration so that chrome can run in a headless manner.

# %%
# Setup webdriver
chrome_driver = webdriver.Chrome(
    executable_path=PATH_TO_CHROME_DRIVER,
    options=CHROME_OPTIONS,
    desired_capabilities=CAPABILITIES
)

# Create dataframe to save information to
company_values_df = pd.DataFrame(columns=HEADERS)

# Get information about all companies
for ndx in range(COMPANY_START, COMPANY_END+1):
    list_of_values = retrieve_company_values(ndx, chrome_driver)
    cur_company_values_df = pd.DataFrame.from_records(list_of_values, columns=Fsvc._fields)
    company_values_df = pd.concat([company_values_df, cur_company_values_df], axis=0)
    print(f"Company Name: {list_of_values[0].company} -- Status: Information Retrieved...")
    
# At this point we've successfully scraped all of the information
# Let's close our connection and save our information to a csv file
chrome_driver.quit()
with open("culture500_data.csv", "a") as culture500_file:
    culture500_file.write(company_values_df.to_csv(index=False))
# Out:
# Company Name: 3M -- Status: Information Retrieved...
# Company Name: Anheuser-Busch InBev -- Status: Information Retrieved...
# Company Name: ABB -- Status: Information Retrieved...
# Company Name: Abbott Laboratories -- Status: Information Retrieved...
# Company Name: AbbVie -- Status: Information Retrieved...
# Company Name: Abercrombie & Fitch -- Status: Information Retrieved...
# Company Name: Accenture -- Status: Information Retrieved...
# Company Name: Adobe -- Status: Information Retrieved...
# Company Name: ADP -- Status: Information Retrieved...
# Company Name: AdventHealth -- Status: Information Retrieved...
# Company Name: Advisory Board -- Status: Information Retrieved...
# Company Name: Advocate Health Care -- Status: Information Retrieved...
# Company Name: Aecom -- Status: Information Retrieved...
# Company Name: Aéropostale -- Status: Information Retrieved...
# Company Name: Aetna -- Status: Information Retrieved...
# Company Name: Aflac -- Status: Information Retrieved...
# Company Name: AIG -- Status: Information Retrieved...
# Company Name: Airbnb -- Status: Information Retrieved...
# Company Name: Alaska Airlines -- Status: Information Retrieved...
# Company Name: Albertsons -- Status: Information Retrieved...
# Company Name: Alcatel-Lucent -- Status: Information Retrieved...
# Company Name: Alcon -- Status: Information Retrieved...
# Company Name: Aldi -- Status: Information Retrieved...
# Company Name: Allergan -- Status: Information Retrieved...
# Company Name: Allscripts -- Status: Information Retrieved...
# Company Name: Allstate -- Status: Information Retrieved...
# Company Name: Ally Financial -- Status: Information Retrieved...
# Company Name: Alphabet (Parent company of Google) -- Status: Information Retrieved...
# Company Name: Amazon -- Status: Information Retrieved...
# Company Name: AMD -- Status: Information Retrieved...
# Company Name: Amdocs -- Status: Information Retrieved...
# Company Name: Amedisys -- Status: Information Retrieved...
# Company Name: American Airlines -- Status: Information Retrieved...
# Company Name: American Eagle Outfitters -- Status: Information Retrieved...
# Company Name: American Express -- Status: Information Retrieved...
# Company Name: Ameriprise Financial -- Status: Information Retrieved...
# Company Name: American Family Insurance -- Status: Information Retrieved...
# Company Name: Amgen -- Status: Information Retrieved...
# Company Name: Ann Inc. -- Status: Information Retrieved...
# Company Name: Anthem -- Status: Information Retrieved...
# Company Name: Anthropologie -- Status: Information Retrieved...
# Company Name: Aon -- Status: Information Retrieved...
# Company Name: Apple -- Status: Information Retrieved...
# Company Name: Applied Materials -- Status: Information Retrieved...
# Company Name: Apria Healthcare -- Status: Information Retrieved...
# Company Name: Arby’s -- Status: Information Retrieved...
# Company Name: Arrow Electronics -- Status: Information Retrieved...
# Company Name: Ascension  -- Status: Information Retrieved...
# Company Name: AstraZeneca -- Status: Information Retrieved...
# Company Name: Asurion -- Status: Information Retrieved...
# Company Name: AT&T -- Status: Information Retrieved...
# Company Name: Atrium Health -- Status: Information Retrieved...
# Company Name: Autodesk -- Status: Information Retrieved...
# Company Name: Avis Budget Group -- Status: Information Retrieved...
# Company Name: Avnet -- Status: Information Retrieved...
# Company Name: Avon Products -- Status: Information Retrieved...
# Company Name: Bain & Company -- Status: Information Retrieved...
# Company Name: Baker Hughes -- Status: Information Retrieved...
# Company Name: Banana Republic -- Status: Information Retrieved...
# Company Name: Bank of America -- Status: Information Retrieved...
# Company Name: Banner Health -- Status: Information Retrieved...
# Company Name: Barclays -- Status: Information Retrieved...
# Company Name: Baxter -- Status: Information Retrieved...
# Company Name: Bayer -- Status: Information Retrieved...
# Company Name: Baylor Scott & White Health -- Status: Information Retrieved...
# Company Name: BB&T -- Status: Information Retrieved...
# Company Name: BBVA Compass -- Status: Information Retrieved...
# Company Name: Boston Consulting Group -- Status: Information Retrieved...
# Company Name: BD   -- Status: Information Retrieved...
# Company Name: Bechtel -- Status: Information Retrieved...
# Company Name: Benefitfocus -- Status: Information Retrieved...
# Company Name: Best Western -- Status: Information Retrieved...
# Company Name: Big Lots -- Status: Information Retrieved...
# Company Name: Biogen -- Status: Information Retrieved...
# Company Name: BJ’s Wholesale Club -- Status: Information Retrieved...
# Company Name: BlackRock -- Status: Information Retrieved...
# Company Name: Bloomberg L.P. -- Status: Information Retrieved...
# Company Name: Bloomingdale’s -- Status: Information Retrieved...
# Company Name: Bristol-Myers Squibb -- Status: Information Retrieved...
# Company Name: BNY Mellon -- Status: Information Retrieved...
# Company Name: Boeing -- Status: Information Retrieved...
# Company Name: Booz Allen Hamilton -- Status: Information Retrieved...
# Company Name: Bose -- Status: Information Retrieved...
# Company Name: Boston Scientific -- Status: Information Retrieved...
# Company Name: BP -- Status: Information Retrieved...
# Company Name: Broadcom -- Status: Information Retrieved...
# Company Name: Brocade Communications Systems -- Status: Information Retrieved...
# Company Name: Brookdale Senior Living -- Status: Information Retrieved...
# Company Name: Burger King -- Status: Information Retrieved...
# Company Name: Burlington Stores -- Status: Information Retrieved...
# Company Name: C.H. Robinson -- Status: Information Retrieved...
# Company Name: CA Technologies -- Status: Information Retrieved...
# Company Name: Cablevision Systems -- Status: Information Retrieved...
# Company Name: CACI International -- Status: Information Retrieved...
# Company Name: Caesars Entertainment -- Status: Information Retrieved...
# Company Name: Campbell Soup Company -- Status: Information Retrieved...
# Company Name: Capgemini -- Status: Information Retrieved...
# Company Name: Capital Group -- Status: Information Retrieved...
# Company Name: Capital One -- Status: Information Retrieved...
# Company Name: Carnival -- Status: Information Retrieved...
# Company Name: CBS Interactive -- Status: Information Retrieved...
# Company Name: CDK Global -- Status: Information Retrieved...
# Company Name: CDW -- Status: Information Retrieved...
# Company Name: Centene -- Status: Information Retrieved...
# Company Name: CenturyLink -- Status: Information Retrieved...
# Company Name: Ceridian -- Status: Information Retrieved...
# Company Name: Cerner -- Status: Information Retrieved...
# Company Name: CGI -- Status: Information Retrieved...
# Company Name: CH2M -- Status: Information Retrieved...
# Company Name: Charles Schwab -- Status: Information Retrieved...
# Company Name: Charter Communications -- Status: Information Retrieved...
# Company Name: Chase -- Status: Information Retrieved...
# Company Name: Chevron -- Status: Information Retrieved...
# Company Name: Catholic Health Initiatives -- Status: Information Retrieved...
# Company Name: Chick-fil-A -- Status: Information Retrieved...
# Company Name: Chipotle -- Status: Information Retrieved...
# Company Name: Choice Hotels -- Status: Information Retrieved...
# Company Name: Community Health Systems -- Status: Information Retrieved...
# Company Name: Chubb -- Status: Information Retrieved...
# Company Name: Cigna -- Status: Information Retrieved...
# Company Name: Cisco Systems -- Status: Information Retrieved...
# Company Name: Citi -- Status: Information Retrieved...
# Company Name: Citizens Bank -- Status: Information Retrieved...
# Company Name: Citrix -- Status: Information Retrieved...
# Company Name: Cleveland Clinic -- Status: Information Retrieved...
# Company Name: The Clorox Company -- Status: Information Retrieved...
# Company Name: Coach -- Status: Information Retrieved...
# Company Name: Coca-Cola Company -- Status: Information Retrieved...
# Company Name: Cognizant -- Status: Information Retrieved...
# Company Name: Colgate-Palmolive -- Status: Information Retrieved...
# Company Name: Collins Aerospace -- Status: Information Retrieved...
# Company Name: Comcast -- Status: Information Retrieved...
# Company Name: Comerica -- Status: Information Retrieved...
# Company Name: CompuCom -- Status: Information Retrieved...
# Company Name: Conagra Brands -- Status: Information Retrieved...
# Company Name: Conduent -- Status: Information Retrieved...
# Company Name: ConocoPhillips -- Status: Information Retrieved...
# Company Name: Convergys -- Status: Information Retrieved...
# Company Name: Costco Wholesale -- Status: Information Retrieved...
# Company Name: Covidien -- Status: Information Retrieved...
# Company Name: Cox Communications -- Status: Information Retrieved...
# Company Name: Credit Suisse -- Status: Information Retrieved...
# Company Name: CSAA Insurance Group -- Status: Information Retrieved...
# Company Name: CSC -- Status: Information Retrieved...
# Company Name: Cummins -- Status: Information Retrieved...
# Company Name: CVS Health -- Status: Information Retrieved...
# Company Name: Dairy Queen -- Status: Information Retrieved...
# Company Name: Danaher -- Status: Information Retrieved...
# Company Name: DaVita -- Status: Information Retrieved...
# Company Name: Dell -- Status: Information Retrieved...
# Company Name: Deloitte -- Status: Information Retrieved...
# Company Name: Delta Air Lines -- Status: Information Retrieved...
# Company Name: Deutsche Bank -- Status: Information Retrieved...
# Company Name: Diebold Nixdorf -- Status: Information Retrieved...
# Company Name: Dignity Health -- Status: Information Retrieved...
# Company Name: Dillard’s -- Status: Information Retrieved...
# Company Name: Discover -- Status: Information Retrieved...
# Company Name: Discovery, Inc.  -- Status: Information Retrieved...
# Company Name: Dish Network -- Status: Information Retrieved...
# Company Name: The Walt Disney Company -- Status: Information Retrieved...
# Company Name: Disney Parks, Experiences and Products -- Status: Information Retrieved...
# Company Name: Dollar General -- Status: Information Retrieved...
# Company Name: Dollar Tree -- Status: Information Retrieved...
# Company Name: Domino’s -- Status: Information Retrieved...
# Company Name: DoorDash -- Status: Information Retrieved...
# Company Name: Dow Chemical Company -- Status: Information Retrieved...
# Company Name: Dow Jones -- Status: Information Retrieved...
# Company Name: Dr Pepper Snapple Group -- Status: Information Retrieved...
# Company Name: Dunkin’ -- Status: Information Retrieved...
# Company Name: DuPont -- Status: Information Retrieved...
# Company Name: DXC Technology -- Status: Information Retrieved...
# Company Name: E-Trade Financial -- Status: Information Retrieved...
# Company Name: Electronic Arts -- Status: Information Retrieved...
# Company Name: Eaton -- Status: Information Retrieved...
# Company Name: eBay -- Status: Information Retrieved...
# Company Name: Edward Jones -- Status: Information Retrieved...
# Company Name: Edwards Lifesciences -- Status: Information Retrieved...
# Company Name: Eli Lilly and Company -- Status: Information Retrieved...
# Company Name: Dell EMC -- Status: Information Retrieved...
# Company Name: Emerson -- Status: Information Retrieved...
# Company Name: Enterprise -- Status: Information Retrieved...
# Company Name: Equifax -- Status: Information Retrieved...
# Company Name: Ericsson -- Status: Information Retrieved...
# Company Name: ESPN -- Status: Information Retrieved...
# Company Name: Estée Lauder Companies -- Status: Information Retrieved...
# Company Name: Expedia -- Status: Information Retrieved...
# Company Name: Expeditors -- Status: Information Retrieved...
# Company Name: Experian -- Status: Information Retrieved...
# Company Name: ExxonMobil -- Status: Information Retrieved...
# Company Name: EY -- Status: Information Retrieved...
# Company Name: Facebook -- Status: Information Retrieved...
# Company Name: Family Dollar -- Status: Information Retrieved...
# Company Name: Farmers Insurance Group -- Status: Information Retrieved...
# Company Name: Fastenal -- Status: Information Retrieved...
# Company Name: Fiat Chrysler Automobiles -- Status: Information Retrieved...
# Company Name: FedEx -- Status: Information Retrieved...
# Company Name: Fidelity Investments -- Status: Information Retrieved...
# Company Name: Fifth Third Bank -- Status: Information Retrieved...
# Company Name: First Data -- Status: Information Retrieved...
# Company Name: FIS -- Status: Information Retrieved...
# Company Name: Fiserv -- Status: Information Retrieved...
# Company Name: Five Guys -- Status: Information Retrieved...
# Company Name: Flex -- Status: Information Retrieved...
# Company Name: Fluor -- Status: Information Retrieved...
# Company Name: Food Lion -- Status: Information Retrieved...
# Company Name: Ford Motor Company -- Status: Information Retrieved...
# Company Name: Fossil Group -- Status: Information Retrieved...
# Company Name: Four Seasons -- Status: Information Retrieved...
# Company Name: Fred Meyer -- Status: Information Retrieved...
# Company Name: Fresenius Medical Care - North America -- Status: Information Retrieved...
# Company Name: The Fresh Market -- Status: Information Retrieved...
# Company Name: Frontier Communications -- Status: Information Retrieved...
# Company Name: Gartner -- Status: Information Retrieved...
# Company Name: General Electric -- Status: Information Retrieved...
# Company Name: GE Aviation -- Status: Information Retrieved...
# Company Name: GE Healthcare -- Status: Information Retrieved...
# Company Name: Geico -- Status: Information Retrieved...
# Company Name: Genentech -- Status: Information Retrieved...
# Company Name: General Dynamics -- Status: Information Retrieved...
# Company Name: General Mills -- Status: Information Retrieved...
# Company Name: General Motors -- Status: Information Retrieved...
# Company Name: Genesis HealthCare -- Status: Information Retrieved...
# Company Name: Giant Eagle -- Status: Information Retrieved...
# Company Name: Giant Food Stores -- Status: Information Retrieved...
# Company Name: Gilead Sciences -- Status: Information Retrieved...
# Company Name: GlobalFoundries -- Status: Information Retrieved...
# Company Name: GoDaddy -- Status: Information Retrieved...
# Company Name: Goldman Sachs -- Status: Information Retrieved...
# Company Name: Groupon -- Status: Information Retrieved...
# Company Name: Grubhub -- Status: Information Retrieved...
# Company Name: GlaxoSmithKline -- Status: Information Retrieved...
# Company Name: H-E-B -- Status: Information Retrieved...
# Company Name: H&M -- Status: Information Retrieved...
# Company Name: Halliburton -- Status: Information Retrieved...
# Company Name: Harris -- Status: Information Retrieved...
# Company Name: Harris Teeter -- Status: Information Retrieved...
# Company Name: HBO -- Status: Information Retrieved...
# Company Name: HCA Healthcare -- Status: Information Retrieved...
# Company Name: HCL Technologies -- Status: Information Retrieved...
# Company Name: HCR ManorCare -- Status: Information Retrieved...
# Company Name: HCSC -- Status: Information Retrieved...
# Company Name: HD Supply -- Status: Information Retrieved...
# Company Name: Henkel -- Status: Information Retrieved...
# Company Name: The Hershey Company -- Status: Information Retrieved...
# Company Name: Hertz -- Status: Information Retrieved...
# Company Name: Highmark Health -- Status: Information Retrieved...
# Company Name: Hill-Rom -- Status: Information Retrieved...
# Company Name: Hilton -- Status: Information Retrieved...
# Company Name: Home Instead Senior Care -- Status: Information Retrieved...
# Company Name: Honeywell -- Status: Information Retrieved...
# Company Name: Hospira -- Status: Information Retrieved...
# Company Name: Hewlett Packard Enterprise -- Status: Information Retrieved...
# Company Name: HP Inc. -- Status: Information Retrieved...
# Company Name: HSBC Holdings -- Status: Information Retrieved...
# Company Name: Huawei Technologies -- Status: Information Retrieved...
# Company Name: Humana -- Status: Information Retrieved...
# Company Name: Huntington National Bank -- Status: Information Retrieved...
# Company Name: Hy-Vee -- Status: Information Retrieved...
# Company Name: Hyatt -- Status: Information Retrieved...
# Company Name: IBM -- Status: Information Retrieved...
# Company Name: Illumina -- Status: Information Retrieved...
# Company Name: In-N-Out Burger -- Status: Information Retrieved...
# Company Name: Infor -- Status: Information Retrieved...
# Company Name: Infosys -- Status: Information Retrieved...
# Company Name: Ingersoll Rand -- Status: Information Retrieved...
# Company Name: Ingram Micro -- Status: Information Retrieved...
# Company Name: Instacart -- Status: Information Retrieved...
# Company Name: Intel Corporation -- Status: Information Retrieved...
# Company Name: InterContinental Hotels Group -- Status: Information Retrieved...
# Company Name: Intermountain Healthcare -- Status: Information Retrieved...
# Company Name: Intuit -- Status: Information Retrieved...
# Company Name: Illinois Tool Works -- Status: Information Retrieved...
# Company Name: J. C. Penney -- Status: Information Retrieved...
# Company Name: J.Crew -- Status: Information Retrieved...
# Company Name: Johnson & Johnson -- Status: Information Retrieved...
# Company Name: Jabil -- Status: Information Retrieved...
# Company Name: Jack Henry & Associates -- Status: Information Retrieved...
# Company Name: Jack in the Box -- Status: Information Retrieved...
# Company Name: Jacobs -- Status: Information Retrieved...
# Company Name: JetBlue -- Status: Information Retrieved...
# Company Name: Johnson Controls -- Status: Information Retrieved...
# Company Name: JoS. A. Bank -- Status: Information Retrieved...
# Company Name: JPMorgan Chase & Co. -- Status: Information Retrieved...
# Company Name: Juniper Networks -- Status: Information Retrieved...
# Company Name: Kaiser Permanente -- Status: Information Retrieved...
# Company Name: Kate Spade & Company -- Status: Information Retrieved...
# Company Name: KBR -- Status: Information Retrieved...
# Company Name: Kellogg Company -- Status: Information Retrieved...
# Company Name: KeyBank -- Status: Information Retrieved...
# Company Name: KFC -- Status: Information Retrieved...
# Company Name: Kiewit Corporation -- Status: Information Retrieved...
# Company Name: Kimberly-Clark -- Status: Information Retrieved...
# Company Name: Kindred Healthcare -- Status: Information Retrieved...
# Company Name: KLA -- Status: Information Retrieved...
# Company Name: Kmart -- Status: Information Retrieved...
# Company Name: Kohl’s -- Status: Information Retrieved...
# Company Name: KPMG -- Status: Information Retrieved...
# Company Name: The Kraft Heinz Company -- Status: Information Retrieved...
# Company Name: Kroger -- Status: Information Retrieved...
# Company Name: Kronos Incorporated -- Status: Information Retrieved...
# Company Name: L’Oréal -- Status: Information Retrieved...
# Company Name: L3 Technologies -- Status: Information Retrieved...
# Company Name: Lam Research -- Status: Information Retrieved...
# Company Name: Leidos -- Status: Information Retrieved...
# Company Name: Lenovo -- Status: Information Retrieved...
# Company Name: Level 3 Communications -- Status: Information Retrieved...
# Company Name: Levi Strauss -- Status: Information Retrieved...
# Company Name: Liberty Mutual Insurance -- Status: Information Retrieved...
# Company Name: Lincoln Financial Group -- Status: Information Retrieved...
# Company Name: LinkedIn -- Status: Information Retrieved...
# Company Name: Lockheed Martin -- Status: Information Retrieved...
# Company Name: Lowe’s -- Status: Information Retrieved...
# Company Name: LPL Financial -- Status: Information Retrieved...
# Company Name: Lululemon Athletica -- Status: Information Retrieved...
# Company Name: Lyft -- Status: Information Retrieved...
# Company Name: M&T Bank -- Status: Information Retrieved...
# Company Name: Macy’s -- Status: Information Retrieved...
# Company Name: Magellan Health -- Status: Information Retrieved...
# Company Name: Marriott International -- Status: Information Retrieved...
# Company Name: Mars  -- Status: Information Retrieved...
# Company Name: Marsh & McLennan Companies -- Status: Information Retrieved...
# Company Name: Marshalls -- Status: Information Retrieved...
# Company Name: MassMutual -- Status: Information Retrieved...
# Company Name: Mastercard -- Status: Information Retrieved...
# Company Name: Maxim Healthcare Services -- Status: Information Retrieved...
# Company Name: McDonald’s -- Status: Information Retrieved...
# Company Name: McKesson -- Status: Information Retrieved...
# Company Name: McKinsey & Company -- Status: Information Retrieved...
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-7-c461f8180bba> in <module>
#      11 # Get information about all companies
#      12 for ndx in range(COMPANY_START, COMPANY_END+1):
# ---> 13     list_of_values = retrieve_company_values(ndx, chrome_driver)
#      14     cur_company_values_df = pd.DataFrame.from_records(list_of_values, columns=Fsvc._fields)
#      15     company_values_df = pd.concat([company_values_df, cur_company_values_df], axis=0)
#
# <ipython-input-6-a794cec59f72> in retrieve_company_values(company_ndx, browser)
#      25         WebDriverWait(browser, delay)
#      26         .until(EC.visibility_of_element_located(
# ---> 27             (By.CSS_SELECTOR, ".sc-bdVaJa.sc-bwzfXH.pjOvZ")
#      28         ))
#      29     )
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/support/wait.py in until(self, method, message)
#      78             if time.time() > end_time:
#      79                 break
# ---> 80         raise TimeoutException(message, screen, stacktrace)
#      81
#      82     def until_not(self, method, message=''):
#
# TimeoutException: Message:
